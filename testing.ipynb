# %%
from sklearn.metrics import roc_auc_score, accuracy_score, confusion_matrix, precision_score, recall_score, classification_report
import os
import kagglehub

path = kagglehub.dataset_download("vinicius150987/titanic3")
excel_path = os.path.join(path, "titanic3.xls")
os.makedirs("images", exist_ok=True)
os.makedirs("models", exist_ok=True)

# %%
try:
    import shutil
    shutil.rmtree("__pycache__")
except:
    pass

# %%
import joblib
X_test = joblib.load("models/artifacts/X_test.pkl")
y_test = joblib.load("models/artifacts/y_test.pkl")

# %%
logistic_model = joblib.load("models/logistic_regression_model.pkl")
y_pred = logistic_model.predict(X_test)
print(accuracy_score(y_test, y_pred))
# Out:
# 0.7900763358778626

# %%
svm_model = joblib.load("models/svm_model.pkl")
y_pred2 = svm_model.predict(X_test)
print(accuracy_score(y_test, y_pred2))
# Out:
# 0.7824427480916031
